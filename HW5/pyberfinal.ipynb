# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# Read the City and Ride Data

city_data = pd.read_csv("data/city_data.csv")
ride_data = pd.read_csv("data/ride_data.csv")

# Combine the data into a single dataset
pyber_combined = pd.merge(city_data, ride_data, on="city", how='outer')


# Display the data table for preview
pyber_combined.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
#df.groupby(['Fruit','Name'])['Number'].sum().reset_index()
pyber_type = pyber_combined.groupby(["type", "driver_count"])["fare"].sum().reset_index()
pyber_type.head()
# Out:
#     type  driver_count     fare
# 0  Rural             1  1198.02
# 1  Rural             2   546.35
# 2  Rural             4   711.98
# 3  Rural             6   596.20
# 4  Rural             7   864.50

# %%
pyber_type["Average Fare"]=pyber_type["fare"]/pyber_type["driver_count"]
pyber_type.head()
# Out:
#     type  driver_count     fare  Average Fare
# 0  Rural             1  1198.02   1198.020000
# 1  Rural             2   546.35    273.175000
# 2  Rural             4   711.98    177.995000
# 3  Rural             6   596.20     99.366667
# 4  Rural             7   864.50    123.500000

# %%
x_limit = 50

x_axis=pyber_combined["driver_count"]
y_axis=pyber_combined["fare"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black",
            s=x_axis, alpha=0.75)

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# Build the scatter plots for each city types

# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
pyber_sums = pyber_combined.groupby("type").sum()
pyber_sums
# Out:
#           driver_count      fare           ride_id
# type
# Rural              537   4327.93   580968240341287
# Suburban          8570  19356.33  3106884522576766
# Urban            59602  39854.38  7919412664056093

# %%
()# Build Pie Chart

labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [4327, 19356, 39854]

# The colors of each section of the pie chart
colors = ["red", "yellow", "lightskyblue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0.1)

# Create axes which are equal so we have a perfect circle
# Calculate Driver Percents
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.show()

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
pyber_city = pyber_combined.groupby("type").count()
pyber_city
# Out:
#           city  driver_count  date  fare  ride_id
# type
# Rural      125           125   125   125      125
# Suburban   625           625   625   625      625
# Urban     1625          1625  1625  1625     1625

# %%
# Build Pie Chart

labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [125, 625, 1625]

# The colors of each section of the pie chart
colors = ["red", "yellow", "lightskyblue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0.1)

# Create axes which are equal so we have a perfect circle
# Calculate Driver Percents
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)
plt.show()

# %% [markdown]
# ## Total Drivers by City Type

# %%
pyber_sums
# Out:
#           driver_count      fare           ride_id
# type
# Rural              537   4327.93   580968240341287
# Suburban          8570  19356.33  3106884522576766
# Urban            59602  39854.38  7919412664056093

# %%
# Build Pie Charts
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [537, 8570, 59602]

# The colors of each section of the pie chart
colors = ["red", "yellow", "lightskyblue"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0.1)

# Create axes which are equal so we have a perfect circle
# Calculate Driver Percents
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=140)


# Save Figure
plt.show()

# %%
# Show Figure
plt.show()
